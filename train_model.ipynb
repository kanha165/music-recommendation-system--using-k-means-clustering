# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv("dataset.csv")
df.head()
# Out:
#              song_name        track_spotify_id  \
# 0                Sadka  4dPeCbg2Op44s9kwyMS3ZT
# 1  Surili Akhiyon Wale  1la0ICQBLfO0lyqsWNwG7l
# 2        Hona Tha Pyar  0KSOLEBixnBYIKNHF1VbzF
# 3            Zehnaseeb  3xF15SqY32Mno3UUMBirhU
# 4         Rait Zara Si  3gOXq3FPPesm7VLPKmef6j
#
#                                   spotify_track_link  \
# 0  https://open.spotify.com/track/4dPeCbg2Op44s9k...
# 1  https://open.spotify.com/track/1la0ICQBLfO0lyq...
# 2  https://open.spotify.com/track/0KSOLEBixnBYIKN...
# 3  https://open.spotify.com/track/3xF15SqY32Mno3U...
# 4  https://open.spotify.com/track/3gOXq3FPPesm7VL...
#
#                                       thumbnail_link           artist_name  \
# 0  https://i.scdn.co/image/ab67616d0000b2731992dd...        Vishal-Shekhar
# 1  https://i.scdn.co/image/ab67616d0000b2730274bd...  Rahat Fateh Ali Khan
# 2  https://i.scdn.co/image/ab67616d0000b27371ef95...            Atif Aslam
# 3  https://i.scdn.co/image/ab67616d0000b2732025db...        Vishal-Shekhar
# 4  https://i.scdn.co/image/ab67616d0000b2736caa52...          Arijit Singh
#
#                 artist_id                                        artist_link  \
# 0  6Mv8GjQa7LKUGCAqa9qqdb  https://open.spotify.com/artist/6Mv8GjQa7LKUGC...
# 1  3OLGltG8UPIea8sA4w0yg0  https://open.spotify.com/artist/3OLGltG8UPIea8...
# 2  2oSONSC9zQ4UonDKnLqksx  https://open.spotify.com/artist/2oSONSC9zQ4Uon...
# 3  6Mv8GjQa7LKUGCAqa9qqdb  https://open.spotify.com/artist/6Mv8GjQa7LKUGC...
# 4  4YRxDV8wJFPHPTeXepOstw  https://open.spotify.com/artist/4YRxDV8wJFPHPT...
#
#    acousticness  danceability  duration_ms  ...  Rock Fusion  Item Number  \
# 0         0.232         0.678     343587.0  ...          NaN          NaN
# 1         0.407         0.517     331747.0  ...          NaN          NaN
# 2         0.571         0.687     221987.0  ...          NaN          NaN
# 3         0.361         0.623     217440.0  ...          NaN          NaN
# 4         0.781         0.563     291462.0  ...          NaN          NaN
#
#    Lyrical Rap  Devotional  Ghazal  Retro  Comedy  Motivational  Wedding  \
# 0          NaN         NaN     NaN    NaN     NaN           NaN      NaN
# 1          NaN         NaN     NaN    NaN     NaN           NaN      NaN
# 2          NaN         NaN     NaN    NaN     NaN           NaN      NaN
# 3          NaN         NaN     NaN    NaN     NaN           NaN      NaN
# 4          NaN         NaN     NaN    NaN     NaN           NaN      NaN
#
#    Festival
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 39 columns]

# %%
features = [
    'acousticness', 
    'danceability', 
    'duration_ms', 
    'energy',
    'speechiness', 
    'tempo', 
    'valence', 
    'instrumentalness',
    'liveness', 
    'loudness'
]

df_features = df[features]

# %%
df_features = df_features.fillna(0)

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(df_features)

# %%
similarity = cosine_similarity(scaled_features)

# %%
model_data = {
    "df": df,
    "similarity": similarity,
    "scaler": scaler,
    "features": features
}

with open("song_recommender.pkl", "wb") as f:
    pickle.dump(model_data, f)

print(" Model trained & PKL saved successfully")
# Out:
#  Model trained & PKL saved successfully
